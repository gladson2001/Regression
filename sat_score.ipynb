# %% [markdown]
# <a href="https://colab.research.google.com/github/gladson2001/Regression/blob/main/sat_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Simple linear regression.csv')
df
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 95  1934  3.54
# 96  1861  3.58
# 97  1931  3.58
# 98  1933  3.59
# 99  1778  3.59
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     100 non-null    int64
#  1   GPA     100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
x = df.iloc[:, :-1]
x
# Out:
#      SAT
# 0   1714
# 1   1664
# 2   1760
# 3   1685
# 4   1693
# ..   ...
# 95  1934
# 96  1861
# 97  1931
# 98  1933
# 99  1778
#
# [100 rows x 1 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     2.40
# 1     2.52
# 2     2.54
# 3     2.74
# 4     2.83
#       ...
# 95    3.54
# 96    3.58
# 97    3.58
# 98    3.59
# 99    3.59
# Name: GPA, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([3.67199037, 3.04680594, 3.49615725, 3.48413447, 3.58181954,
#        3.34286683, 3.0903885 , 3.31130704, 3.1985935 , 3.16703371,
#        3.35939815, 3.24969031, 3.4976601 , 3.37893517, 3.43604336,
#        3.13547392, 3.59233947, 3.62690496, 3.1985935 , 3.4976601 ,
#        3.42702628, 3.54274551, 3.27674156, 3.54575121, 3.49315155,
#        3.40448357, 3.39396364, 3.38795225, 3.37142093, 3.55927683])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred)

# %%
diff=y_pred-y_test
df1=pd.DataFrame({'Actual_value':y_test,'predicted_value':y_pred,'Difference':diff})
# df2=pd.DataFrame(diff,index=False)
df1
# Out:
#     Actual_value  predicted_value  Difference
# 83          3.81         3.671990   -0.138010
# 53          3.42         3.046806   -0.373194
# 70          3.59         3.496157   -0.093843
# 45          3.40         3.484134    0.084134
# 44          3.39         3.581820    0.191820
# 39          3.37         3.342867   -0.027133
# 22          3.20         3.090389   -0.109611
# 80          3.71         3.311307   -0.398693
# 10          3.02         3.198594    0.178594
# 0           2.40         3.167034    0.767034
# 18          3.17         3.359398    0.189398
# 30          3.28         3.249690   -0.030310
# 73          3.60         3.497660   -0.102340
# 33          3.29         3.378935    0.088935
# 90          3.50         3.436043   -0.063957
# 4           2.83         3.135474    0.305474
# 76          3.64         3.592339   -0.047661
# 77          3.65         3.626905   -0.023095
# 12          3.08         3.198594    0.118594
# ...

# %%
from sklearn.metrics import mean_absolute_error
print('MAE is ',mean_absolute_error(y_test,y_pred))
# Out:
# MAE is  0.1584568108137395

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,r2_score
print('Percentage: ',mean_absolute_percentage_error(y_test,y_pred))
print('Sqaured error: ',mean_squared_error(y_test,y_pred))
print('Root squared Error: ',mean_squared_error(y_test,y_pred)**(1/2))
print('R2_score: ',r2_score(y_test,y_pred))
# Out:
# Percentage:  0.05080547355744477
# Sqaured error:  0.049471500920990646
# Root squared Error:  0.22242189847447721
# R2_score:  0.39340452056267294
